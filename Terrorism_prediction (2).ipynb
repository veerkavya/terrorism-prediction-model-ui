# %%
from google.colab import drive
import shutil

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("/content/drive/MyDrive/terrorismData.csv")

# %%
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                     North America    Mexico city  19.371887  -99.086624
# 2                    Southeast Asia        Unknown  15.478598  120.599741
# 3                    Western Europe         Athens  37.997490   23.762728
# 4                         East Asia        Fukouka  33.580412  130.396361
# ...                             ...            ...        ...         ...
# 181686           Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181687   Middle East & North Africa         Jableh  35.407278   35.942679
# 181688               Southeast Asia       Kubentog   6.900742  124.437908
# 181689                   South Asia         Imphal  24.798346   93.940430
# 181690               Southeast Asia  Cotabato City   7.209594  124.241966
#
#                             AttackType  Killed  Wounded  \
# 0                        Assassination     1.0      0.0
# 1          Hostage Taking (Kidnapping)     0.0      0.0
# 2                        Assassination     1.0      0.0
# 3                    Bombing/Explosion     NaN      NaN
# 4       Facility/Infrastructure Attack     NaN      NaN
# ...                                ...     ...      ...
# 181686                   Armed Assault     1.0      2.0
# 181687               Bombing/Explosion     2.0      7.0
# 181688  Facility/Infrastructure Attack     0.0      0.0
# 181689               Bombing/Explosion     0.0      0.0
# 181690               Bombing/Explosion     0.0      0.0
#
#                          Target  \
# 0                  Julio Guzman
# 1       Nadine Chaval, daughter
# 2                      Employee
# 3                  U.S. Embassy
# 4                U.S. Consulate
# ...                         ...
# 181686               Checkpoint
# 181687         Hmeymim Air Base
# 181688                   Houses
# 181689                   Office
# 181690                  Unknown
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                                              Group  \
# 0                                           MANO-D
# 1               23rd of September Communist League
# 2                                          Unknown
# 3                                          Unknown
# 4                                          Unknown
# ...                                            ...
# 181686                                  Al-Shabaab
# 181687                           Muslim extremists
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689                                     Unknown
# 181690                                     Unknown
#
#                         Target_type Weapon_type
# 0       Private Citizens & Property     Unknown
# 1           Government (Diplomatic)     Unknown
# 2               Journalists & Media     Unknown
# 3           Government (Diplomatic)  Explosives
# 4           Government (Diplomatic)  Incendiary
# ...                             ...         ...
# 181686                     Military    Firearms
# 181687                     Military  Explosives
# 181688  Private Citizens & Property  Incendiary
# 181689         Government (General)  Explosives
# 181690                      Unknown  Explosives
#
# [181691 rows x 17 columns]

# %%
df['Killed'].fillna(df['Killed'].mean(), inplace=True)
df['Wounded'].fillna(df['Wounded'].mean(),inplace=True)

df['Wounded'].fillna(df['Wounded'].mean(),inplace=True)
df['Group'].fillna('Unknown',inplace=True)
df['Country'].fillna('Iraq',inplace=True)
# Out:
# <ipython-input-6-4a2bd6945059>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Killed'].fillna(df['Killed'].mean(), inplace=True)
# <ipython-input-6-4a2bd6945059>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Wounded'].fillna(df['Wounded'].mean(),inplace=True)
# <ipython-input-6-4a2bd6945059>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Wounded'].fillna(df['Wounded'].mean(),inplace=True)
# <ipython-input-6-4a2bd6945059>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Group'].fillna('Unknown',inplace=True)
# <ipython-input-6-4a2bd6945059>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Country'].fillna('Iraq',inplace=True)

# %%
df=df.drop(df[df['Group']=="Unknown"].index)
Train,Test=train_test_split(df,train_size=0.3,stratify=df['AttackType'], random_state=42)
Train
df=Train

# %%
df = df.reset_index()

# %%
df
# Out:
#         index  Year  Month  Day         Country                     State  \
# 0       11558  1980      7   30   United States                California
# 1      138216  2014      9   23         Nigeria                     Benue
# 2       30235  1987      2   22     El Salvador              San Salvador
# 3       71602  2000     12   24       Indonesia  North Sumatra (Province)
# 4       11993  1980     10    4     Philippines      Metropolitian Manila
# ...       ...   ...    ...  ...             ...                       ...
# 29667  178232  2017      8   24         Somalia           Middle Shebelle
# 29668   53768  1992     11    3        Colombia                 Antioquia
# 29669  150892  2015      7   21         Somalia                      Gedo
# 29670   36525  1988     12   11  United Kingdom          Northern Ireland
# 29671  138734  2014     10    5           Italy      Trentino-South Tyrol
#
#                             Region           City   Latitude   Longitude  \
# 0                    North America       Torrance  33.835849 -118.340629
# 1               Sub-Saharan Africa  Odokpo-Okpoga   7.184948    9.047396
# 2      Central America & Caribbean   San Salvador  13.692880  -89.199161
# 3                   Southeast Asia          Medan   3.585242   98.675598
# 4                   Southeast Asia         Manila  14.596051  120.978666
# ...                            ...            ...        ...         ...
# 29667           Sub-Saharan Africa      Qaansheeg   2.382883   45.428011
# 29668                South America       Medellin   6.242026  -75.564766
# 29669           Sub-Saharan Africa        Bardere   2.349308   42.280334
# 29670               Western Europe    Londonderry  55.011562   -7.312045
# 29671               Western Europe       Rovereto  45.891695   11.040313
#
#                            AttackType  Killed    Wounded               Target  \
# 0                       Assassination     1.0   0.000000        Chang Lin Lee
# 1      Facility/Infrastructure Attack     0.0   0.000000              Village
# 2      Facility/Infrastructure Attack     0.0   0.000000        Regis theatre
# 3                   Bombing/Explosion     0.0   0.000000  Santo Paulus Church
# 4                   Bombing/Explosion     0.0  10.000000  Hotel (Luxury type)
# ...                               ...     ...        ...                  ...
# 29667                         Unknown     3.0   3.167668             Soldiers
# 29668                   Assassination     1.0   0.000000            Policeman
# 29669                   Armed Assault    36.0  37.000000             Soldiers
# 29670               Bombing/Explosion     0.0   0.000000     Married Quarters
# 29671                 Unarmed Assault     0.0   3.000000        Demonstration
#
#                                                  Summary  \
# 0                                                    NaN
# 1      09/23/2014: Assailants attacked Odokpo-Okpoga ...
# 2                                                    NaN
# 3      12/24/2000: In a near simultaneous string of r...
# 4                                                    NaN
# ...                                                  ...
# 29667  08/24/2017: Assailants attacked a military bas...
# 29668                                                NaN
# 29669  07/21/2015: Assailants attacked military force...
# 29670                                                NaN
# 29671  10/05/2014: Assailants attacked protestors at ...
#
#                                                   Group  \
# 0            Worldwide Organization of Native Taiwanese
# 1                                     Fulani extremists
# 2      Farabundo Marti National Liberation Front (FMLN)
# 3                                  Jemaah Islamiya (JI)
# 4                         April 6th Liberation Movement
# ...                                                 ...
# 29667                                        Al-Shabaab
# 29668                                  Narco-Terrorists
# 29669                                        Al-Shabaab
# 29670                       Irish Republican Army (IRA)
# 29671                                        Anarchists
#
#                           Target_type Weapon_type
# 0         Private Citizens & Property     Unknown
# 1         Private Citizens & Property     Unknown
# 2                            Business  Incendiary
# 3      Religious Figures/Institutions  Explosives
# 4                            Business  Explosives
# ...                               ...         ...
# 29667                        Military     Unknown
# 29668                          Police    Firearms
# 29669                        Military  Explosives
# 29670                        Military  Explosives
# 29671     Private Citizens & Property       Melee
#
# [29672 rows x 18 columns]

# %%
# Define a function to replace outliers with the median
def replace_outliers(df, category_col, value_col, threshold=1.5):
    result_df = df.copy()

    # Group by the category column
    grouped = df.groupby(category_col)

    # Define a function to replace outliers with the median for each group
    def replace_outliers_group(group):
        q1 = group[value_col].quantile(0.25)
        q3 = group[value_col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - threshold * iqr
        upper_bound = q3 + threshold * iqr
        group[value_col] = np.where((group[value_col] < lower_bound) | (group[value_col] > upper_bound),
                                    group[value_col].median(), group[value_col])
        return group

    # Apply the function to each group
    result_df = grouped.apply(replace_outliers_group)

    return result_df

# Replace outliers with the median category-wise
result_df = replace_outliers(df, 'Weapon_type', 'Killed')
df=result_df
# Display the result
print(result_df)
# Out:
#                                                            index  Year  Month  \
# Weapon_type
# Biological                                         9149   117353  2013      5
#                                                    9724   117354  2013      5
#                                                    15538   42192  1990      4
#                                                    26683  117355  2013      5
# Chemical                                           934    135321  2014      7
# ...                                                          ...   ...    ...
# Vehicle (not to include vehicle-borne explosive... 24624  158328  2016      1
#                                                    24987   73127  2001      9
#                                                    27474   54246  1992     11
#                                                    28876  156922  2015     12
#                                                    29639  177863  2017      8
#
#                                                           Day  \
# Weapon_type
# Biological                                         9149    20
#                                                    9724    20
#                                                    15538   15
#                                                    26683   20
# Chemical                                           934     21
# ...                                                       ...
# Vehicle (not to include vehicle-borne explosive... 24624   31
#                                                    24987   11
#                                                    27474   29
#                                                    28876   24
#                                                    29639   12
#
#                                                                            Country  \
# Weapon_type
# Biological                                         9149              United States
#                                                    9724              United States
#                                                    15538                     Japan
#                                                    26683             United States
# Chemical                                           934                    Pakistan
# ...                                                                            ...
# Vehicle (not to include vehicle-borne explosive... 24624  West Bank and Gaza Strip
#                                                    24987             United States
#                                                    27474                 Venezuela
#                                                    28876  West Bank and Gaza Strip
#                                                    29639             United States
#
#                                                                          State  \
# Weapon_type
# Biological                                         9149   District of Columbia
#                                                    9724   District of Columbia
#                                                    15538              Kanagawa
#                                                    26683              New York
# Chemical                                           934             Balochistan
# ...                                                                        ...
# Vehicle (not to include vehicle-borne explosive... 24624             West Bank
#                                                    24987              New York
#                                                    27474               Caracas
#                                                    28876             West Bank
#                                                    29639              Virginia
#
#                                                                               Region  \
# Weapon_type
# Biological                                         9149                North America
#                                                    9724                North America
#                                                    15538                   East Asia
#                                                    26683               North America
# Chemical                                           934                    South Asia
# ...                                                                              ...
# Vehicle (not to include vehicle-borne explosive... 24624  Middle East & North Africa
#                                                    24987               North America
#                                                    27474               South America
#                                                    28876  Middle East & North Africa
#                                                    29639               North America
#
#                                                                       City  \
# Weapon_type
# Biological                                         9149         Washington
#                                                    9724         Washington
#                                                    15538          Yokohama
#                                                    26683     New York City
# Chemical                                           934              Quetta
# ...                                                                    ...
# Vehicle (not to include vehicle-borne explosive... 24624  Beit Ur al-Tahta
#                                                    24987     New York City
#                                                    27474           Caracas
#                                                    28876            Al-Ram
#                                                    29639   Charlottesville
#
#                                                            Latitude  \
# Weapon_type
# Biological                                         9149   38.908642
#                                                    9724   38.908642
#                                                    15538  35.443708
#                                                    26683  40.697132
# Chemical                                           934    30.098261
# ...                                                             ...
# Vehicle (not to include vehicle-borne explosive... 24624  31.895181
#                                                    24987  40.697132
#                                                    27474  10.482834
#                                                    28876  31.853195
#                                                    29639  38.029474
#
#                                                            Longitude  \
# Weapon_type
# Biological                                         9149   -77.015381
#                                                    9724   -77.015381
#                                                    15538  139.638026
#                                                    26683  -73.931351
# Chemical                                           934     66.944481
# ...                                                              ...
# Vehicle (not to include vehicle-borne explosive... 24624   35.083874
#                                                    24987  -73.931351
#                                                    27474  -66.962128
#                                                    28876   35.231167
#                                                    29639  -78.479616
#
#                                                                               AttackType  \
# Weapon_type
# Biological                                         9149                  Unarmed Assault
#                                                    9724                  Unarmed Assault
#                                                    15538                 Unarmed Assault
#                                                    26683                 Unarmed Assault
# Chemical                                           934                   Unarmed Assault
# ...                                                                                  ...
# Vehicle (not to include vehicle-borne explosive... 24624                 Unarmed Assault
#                                                    24987                       Hijacking
#                                                    27474  Facility/Infrastructure Attack
#                                                    28876                 Unarmed Assault
#                                                    29639                 Unarmed Assault
#
#                                                           Killed  Wounded  \
# Weapon_type
# Biological                                         9149      0.0      0.0
#                                                    9724      0.0      0.0
#                                                    15538     0.0      0.0
#                                                    26683     0.0      0.0
# Chemical                                           934       0.0      4.0
# ...                                                          ...      ...
# Vehicle (not to include vehicle-borne explosive... 24624     0.0      1.0
#                                                    24987     1.0   8191.0
#                                                    27474     0.0      0.0
#                                                    28876     1.0      1.0
#                                                    29639     1.0     19.0
#
#                                                                                                      Target  \
# Weapon_type
# Biological                                         9149                             President: Barack Obama
#                                                    9724                                Director: Mark Glaze
#                                                    15538                                Yokosuka Naval Base
#                                                    26683                           Mayor: Michael Bloomberg
# Chemical                                           934                                                Women
# ...                                                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624                                         Checkpoint
#                                                    24987  Passengers and crew members on United Airlines...
#                                                    27474                                Presidential Palace
#                                                    28876                                           Officers
#                                                    29639                                 Counter-protesters
#
#                                                                                                     Summary  \
# Weapon_type
# Biological                                         9149   05/20/2013: A letter containing ricin was mail...
#                                                    9724   05/20/2013: A letter containing ricin was mail...
#                                                    15538                                                NaN
#                                                    26683  05/20/2013: A letter containing ricin was mail...
# Chemical                                           934    07/21/2014: Assailants threw acid in the faces...
# ...                                                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624  01/31/2016: An assailant attempted to ram his ...
#                                                    24987  09/11/2001: This was one of four related attac...
#                                                    27474                                                NaN
#                                                    28876  12/24/2015: An assailant rammed his vehicle in...
#                                                    29639  08/12/2017: An assailant drove his vehicle int...
#
#                                                                                 Group  \
# Weapon_type
# Biological                                         9149   Anti-Gun Control extremists
#                                                    9724   Anti-Gun Control extremists
#                                                    15538               Aum Shinri Kyo
#                                                    26683  Anti-Gun Control extremists
# Chemical                                           934              Muslim extremists
# ...                                                                               ...
# Vehicle (not to include vehicle-borne explosive... 24624       Palestinian Extremists
#                                                    24987                     Al-Qaida
#                                                    27474          Rebel Military Unit
#                                                    28876       Palestinian Extremists
#                                                    29639          Neo-Nazi extremists
#
#                                                                           Target_type  \
# Weapon_type
# Biological                                         9149          Government (General)
#                                                    9724   Private Citizens & Property
#                                                    15538                     Military
#                                                    26683         Government (General)
# Chemical                                           934    Private Citizens & Property
# ...                                                                               ...
# Vehicle (not to include vehicle-borne explosive... 24624                     Military
#                                                    24987  Private Citizens & Property
#                                                    27474         Government (General)
#                                                    28876                       Police
#                                                    29639  Private Citizens & Property
#
#                                                                                                 Weapon_type
# Weapon_type
# Biological                                         9149                                          Biological
#                                                    9724                                          Biological
#                                                    15538                                         Biological
#                                                    26683                                         Biological
# Chemical                                           934                                             Chemical
# ...                                                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624  Vehicle (not to include vehicle-borne explosiv...
#                                                    24987  Vehicle (not to include vehicle-borne explosiv...
#                                                    27474  Vehicle (not to include vehicle-borne explosiv...
#                                                    28876  Vehicle (not to include vehicle-borne explosiv...
#                                                    29639  Vehicle (not to include vehicle-borne explosiv...
#
# [29672 rows x 18 columns]
# <ipython-input-10-7c1cc386c714>:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = grouped.apply(replace_outliers_group)

# %%
df
# Out:
#                                                            index  Year  Month  \
# Weapon_type
# Biological                                         9149   117353  2013      5
#                                                    9724   117354  2013      5
#                                                    15538   42192  1990      4
#                                                    26683  117355  2013      5
# Chemical                                           934    135321  2014      7
# ...                                                          ...   ...    ...
# Vehicle (not to include vehicle-borne explosive... 24624  158328  2016      1
#                                                    24987   73127  2001      9
#                                                    27474   54246  1992     11
#                                                    28876  156922  2015     12
#                                                    29639  177863  2017      8
#
#                                                           Day  \
# Weapon_type
# Biological                                         9149    20
#                                                    9724    20
#                                                    15538   15
#                                                    26683   20
# Chemical                                           934     21
# ...                                                       ...
# Vehicle (not to include vehicle-borne explosive... 24624   31
#                                                    24987   11
#                                                    27474   29
#                                                    28876   24
#                                                    29639   12
#
#                                                                            Country  \
# Weapon_type
# Biological                                         9149              United States
#                                                    9724              United States
#                                                    15538                     Japan
#                                                    26683             United States
# Chemical                                           934                    Pakistan
# ...                                                                            ...
# Vehicle (not to include vehicle-borne explosive... 24624  West Bank and Gaza Strip
#                                                    24987             United States
#                                                    27474                 Venezuela
#                                                    28876  West Bank and Gaza Strip
#                                                    29639             United States
#
#                                                                          State  \
# Weapon_type
# Biological                                         9149   District of Columbia
#                                                    9724   District of Columbia
#                                                    15538              Kanagawa
#                                                    26683              New York
# Chemical                                           934             Balochistan
# ...                                                                        ...
# Vehicle (not to include vehicle-borne explosive... 24624             West Bank
#                                                    24987              New York
#                                                    27474               Caracas
#                                                    28876             West Bank
#                                                    29639              Virginia
#
#                                                                               Region  \
# Weapon_type
# Biological                                         9149                North America
#                                                    9724                North America
#                                                    15538                   East Asia
#                                                    26683               North America
# Chemical                                           934                    South Asia
# ...                                                                              ...
# Vehicle (not to include vehicle-borne explosive... 24624  Middle East & North Africa
#                                                    24987               North America
#                                                    27474               South America
#                                                    28876  Middle East & North Africa
#                                                    29639               North America
#
#                                                                       City  \
# Weapon_type
# Biological                                         9149         Washington
#                                                    9724         Washington
#                                                    15538          Yokohama
#                                                    26683     New York City
# Chemical                                           934              Quetta
# ...                                                                    ...
# Vehicle (not to include vehicle-borne explosive... 24624  Beit Ur al-Tahta
#                                                    24987     New York City
#                                                    27474           Caracas
#                                                    28876            Al-Ram
#                                                    29639   Charlottesville
#
#                                                            Latitude  \
# Weapon_type
# Biological                                         9149   38.908642
#                                                    9724   38.908642
#                                                    15538  35.443708
#                                                    26683  40.697132
# Chemical                                           934    30.098261
# ...                                                             ...
# Vehicle (not to include vehicle-borne explosive... 24624  31.895181
#                                                    24987  40.697132
#                                                    27474  10.482834
#                                                    28876  31.853195
#                                                    29639  38.029474
#
#                                                            Longitude  \
# Weapon_type
# Biological                                         9149   -77.015381
#                                                    9724   -77.015381
#                                                    15538  139.638026
#                                                    26683  -73.931351
# Chemical                                           934     66.944481
# ...                                                              ...
# Vehicle (not to include vehicle-borne explosive... 24624   35.083874
#                                                    24987  -73.931351
#                                                    27474  -66.962128
#                                                    28876   35.231167
#                                                    29639  -78.479616
#
#                                                                               AttackType  \
# Weapon_type
# Biological                                         9149                  Unarmed Assault
#                                                    9724                  Unarmed Assault
#                                                    15538                 Unarmed Assault
#                                                    26683                 Unarmed Assault
# Chemical                                           934                   Unarmed Assault
# ...                                                                                  ...
# Vehicle (not to include vehicle-borne explosive... 24624                 Unarmed Assault
#                                                    24987                       Hijacking
#                                                    27474  Facility/Infrastructure Attack
#                                                    28876                 Unarmed Assault
#                                                    29639                 Unarmed Assault
#
#                                                           Killed  Wounded  \
# Weapon_type
# Biological                                         9149      0.0      0.0
#                                                    9724      0.0      0.0
#                                                    15538     0.0      0.0
#                                                    26683     0.0      0.0
# Chemical                                           934       0.0      4.0
# ...                                                          ...      ...
# Vehicle (not to include vehicle-borne explosive... 24624     0.0      1.0
#                                                    24987     1.0   8191.0
#                                                    27474     0.0      0.0
#                                                    28876     1.0      1.0
#                                                    29639     1.0     19.0
#
#                                                                                                      Target  \
# Weapon_type
# Biological                                         9149                             President: Barack Obama
#                                                    9724                                Director: Mark Glaze
#                                                    15538                                Yokosuka Naval Base
#                                                    26683                           Mayor: Michael Bloomberg
# Chemical                                           934                                                Women
# ...                                                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624                                         Checkpoint
#                                                    24987  Passengers and crew members on United Airlines...
#                                                    27474                                Presidential Palace
#                                                    28876                                           Officers
#                                                    29639                                 Counter-protesters
#
#                                                                                                     Summary  \
# Weapon_type
# Biological                                         9149   05/20/2013: A letter containing ricin was mail...
#                                                    9724   05/20/2013: A letter containing ricin was mail...
#                                                    15538                                                NaN
#                                                    26683  05/20/2013: A letter containing ricin was mail...
# Chemical                                           934    07/21/2014: Assailants threw acid in the faces...
# ...                                                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624  01/31/2016: An assailant attempted to ram his ...
#                                                    24987  09/11/2001: This was one of four related attac...
#                                                    27474                                                NaN
#                                                    28876  12/24/2015: An assailant rammed his vehicle in...
#                                                    29639  08/12/2017: An assailant drove his vehicle int...
#
#                                                                                 Group  \
# Weapon_type
# Biological                                         9149   Anti-Gun Control extremists
#                                                    9724   Anti-Gun Control extremists
#                                                    15538               Aum Shinri Kyo
#                                                    26683  Anti-Gun Control extremists
# Chemical                                           934              Muslim extremists
# ...                                                                               ...
# Vehicle (not to include vehicle-borne explosive... 24624       Palestinian Extremists
#                                                    24987                     Al-Qaida
#                                                    27474          Rebel Military Unit
#                                                    28876       Palestinian Extremists
#                                                    29639          Neo-Nazi extremists
#
#                                                                           Target_type  \
# Weapon_type
# Biological                                         9149          Government (General)
#                                                    9724   Private Citizens & Property
#                                                    15538                     Military
#                                                    26683         Government (General)
# Chemical                                           934    Private Citizens & Property
# ...                                                                               ...
# Vehicle (not to include vehicle-borne explosive... 24624                     Military
#                                                    24987  Private Citizens & Property
#                                                    27474         Government (General)
#                                                    28876                       Police
#                                                    29639  Private Citizens & Property
#
#                                                                                                 Weapon_type
# Weapon_type
# Biological                                         9149                                          Biological
#                                                    9724                                          Biological
#                                                    15538                                         Biological
#                                                    26683                                         Biological
# Chemical                                           934                                             Chemical
# ...                                                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624  Vehicle (not to include vehicle-borne explosiv...
#                                                    24987  Vehicle (not to include vehicle-borne explosiv...
#                                                    27474  Vehicle (not to include vehicle-borne explosiv...
#                                                    28876  Vehicle (not to include vehicle-borne explosiv...
#                                                    29639  Vehicle (not to include vehicle-borne explosiv...
#
# [29672 rows x 18 columns]

# %%
df=result_df

# %%
df
# Out:
#                                                            index  Year  Month  \
# Weapon_type
# Biological                                         9149   117353  2013      5
#                                                    9724   117354  2013      5
#                                                    15538   42192  1990      4
#                                                    26683  117355  2013      5
# Chemical                                           934    135321  2014      7
# ...                                                          ...   ...    ...
# Vehicle (not to include vehicle-borne explosive... 24624  158328  2016      1
#                                                    24987   73127  2001      9
#                                                    27474   54246  1992     11
#                                                    28876  156922  2015     12
#                                                    29639  177863  2017      8
#
#                                                           Day  \
# Weapon_type
# Biological                                         9149    20
#                                                    9724    20
#                                                    15538   15
#                                                    26683   20
# Chemical                                           934     21
# ...                                                       ...
# Vehicle (not to include vehicle-borne explosive... 24624   31
#                                                    24987   11
#                                                    27474   29
#                                                    28876   24
#                                                    29639   12
#
#                                                                            Country  \
# Weapon_type
# Biological                                         9149              United States
#                                                    9724              United States
#                                                    15538                     Japan
#                                                    26683             United States
# Chemical                                           934                    Pakistan
# ...                                                                            ...
# Vehicle (not to include vehicle-borne explosive... 24624  West Bank and Gaza Strip
#                                                    24987             United States
#                                                    27474                 Venezuela
#                                                    28876  West Bank and Gaza Strip
#                                                    29639             United States
#
#                                                                          State  \
# Weapon_type
# Biological                                         9149   District of Columbia
#                                                    9724   District of Columbia
#                                                    15538              Kanagawa
#                                                    26683              New York
# Chemical                                           934             Balochistan
# ...                                                                        ...
# Vehicle (not to include vehicle-borne explosive... 24624             West Bank
#                                                    24987              New York
#                                                    27474               Caracas
#                                                    28876             West Bank
#                                                    29639              Virginia
#
#                                                                               Region  \
# Weapon_type
# Biological                                         9149                North America
#                                                    9724                North America
#                                                    15538                   East Asia
#                                                    26683               North America
# Chemical                                           934                    South Asia
# ...                                                                              ...
# Vehicle (not to include vehicle-borne explosive... 24624  Middle East & North Africa
#                                                    24987               North America
#                                                    27474               South America
#                                                    28876  Middle East & North Africa
#                                                    29639               North America
#
#                                                                       City  \
# Weapon_type
# Biological                                         9149         Washington
#                                                    9724         Washington
#                                                    15538          Yokohama
#                                                    26683     New York City
# Chemical                                           934              Quetta
# ...                                                                    ...
# Vehicle (not to include vehicle-borne explosive... 24624  Beit Ur al-Tahta
#                                                    24987     New York City
#                                                    27474           Caracas
#                                                    28876            Al-Ram
#                                                    29639   Charlottesville
#
#                                                            Latitude  \
# Weapon_type
# Biological                                         9149   38.908642
#                                                    9724   38.908642
#                                                    15538  35.443708
#                                                    26683  40.697132
# Chemical                                           934    30.098261
# ...                                                             ...
# Vehicle (not to include vehicle-borne explosive... 24624  31.895181
#                                                    24987  40.697132
#                                                    27474  10.482834
#                                                    28876  31.853195
#                                                    29639  38.029474
#
#                                                            Longitude  \
# Weapon_type
# Biological                                         9149   -77.015381
#                                                    9724   -77.015381
#                                                    15538  139.638026
#                                                    26683  -73.931351
# Chemical                                           934     66.944481
# ...                                                              ...
# Vehicle (not to include vehicle-borne explosive... 24624   35.083874
#                                                    24987  -73.931351
#                                                    27474  -66.962128
#                                                    28876   35.231167
#                                                    29639  -78.479616
#
#                                                                               AttackType  \
# Weapon_type
# Biological                                         9149                  Unarmed Assault
#                                                    9724                  Unarmed Assault
#                                                    15538                 Unarmed Assault
#                                                    26683                 Unarmed Assault
# Chemical                                           934                   Unarmed Assault
# ...                                                                                  ...
# Vehicle (not to include vehicle-borne explosive... 24624                 Unarmed Assault
#                                                    24987                       Hijacking
#                                                    27474  Facility/Infrastructure Attack
#                                                    28876                 Unarmed Assault
#                                                    29639                 Unarmed Assault
#
#                                                           Killed  Wounded  \
# Weapon_type
# Biological                                         9149      0.0      0.0
#                                                    9724      0.0      0.0
#                                                    15538     0.0      0.0
#                                                    26683     0.0      0.0
# Chemical                                           934       0.0      4.0
# ...                                                          ...      ...
# Vehicle (not to include vehicle-borne explosive... 24624     0.0      1.0
#                                                    24987     1.0   8191.0
#                                                    27474     0.0      0.0
#                                                    28876     1.0      1.0
#                                                    29639     1.0     19.0
#
#                                                                                                      Target  \
# Weapon_type
# Biological                                         9149                             President: Barack Obama
#                                                    9724                                Director: Mark Glaze
#                                                    15538                                Yokosuka Naval Base
#                                                    26683                           Mayor: Michael Bloomberg
# Chemical                                           934                                                Women
# ...                                                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624                                         Checkpoint
#                                                    24987  Passengers and crew members on United Airlines...
#                                                    27474                                Presidential Palace
#                                                    28876                                           Officers
#                                                    29639                                 Counter-protesters
#
#                                                                                                     Summary  \
# Weapon_type
# Biological                                         9149   05/20/2013: A letter containing ricin was mail...
#                                                    9724   05/20/2013: A letter containing ricin was mail...
#                                                    15538                                                NaN
#                                                    26683  05/20/2013: A letter containing ricin was mail...
# Chemical                                           934    07/21/2014: Assailants threw acid in the faces...
# ...                                                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624  01/31/2016: An assailant attempted to ram his ...
#                                                    24987  09/11/2001: This was one of four related attac...
#                                                    27474                                                NaN
#                                                    28876  12/24/2015: An assailant rammed his vehicle in...
#                                                    29639  08/12/2017: An assailant drove his vehicle int...
#
#                                                                                 Group  \
# Weapon_type
# Biological                                         9149   Anti-Gun Control extremists
#                                                    9724   Anti-Gun Control extremists
#                                                    15538               Aum Shinri Kyo
#                                                    26683  Anti-Gun Control extremists
# Chemical                                           934              Muslim extremists
# ...                                                                               ...
# Vehicle (not to include vehicle-borne explosive... 24624       Palestinian Extremists
#                                                    24987                     Al-Qaida
#                                                    27474          Rebel Military Unit
#                                                    28876       Palestinian Extremists
#                                                    29639          Neo-Nazi extremists
#
#                                                                           Target_type  \
# Weapon_type
# Biological                                         9149          Government (General)
#                                                    9724   Private Citizens & Property
#                                                    15538                     Military
#                                                    26683         Government (General)
# Chemical                                           934    Private Citizens & Property
# ...                                                                               ...
# Vehicle (not to include vehicle-borne explosive... 24624                     Military
#                                                    24987  Private Citizens & Property
#                                                    27474         Government (General)
#                                                    28876                       Police
#                                                    29639  Private Citizens & Property
#
#                                                                                                 Weapon_type
# Weapon_type
# Biological                                         9149                                          Biological
#                                                    9724                                          Biological
#                                                    15538                                         Biological
#                                                    26683                                         Biological
# Chemical                                           934                                             Chemical
# ...                                                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624  Vehicle (not to include vehicle-borne explosiv...
#                                                    24987  Vehicle (not to include vehicle-borne explosiv...
#                                                    27474  Vehicle (not to include vehicle-borne explosiv...
#                                                    28876  Vehicle (not to include vehicle-borne explosiv...
#                                                    29639  Vehicle (not to include vehicle-borne explosiv...
#
# [29672 rows x 18 columns]

# %%
cc=df['Group'].value_counts()
df['Group']=df['Group'].map(cc)

# %%
#manual
df['AttackType'] = df['AttackType'].map(
                   {'Bombing/Explosion':1 ,'Assassination':2,'Unarmed Assault':3,'Armed Assault':4,'Facility/Infrastructure Attack':5,'Hostage Taking (Kidnapping)':6,'Hijacking':7, 'Unknown':8,'Hostage Taking (Barricade Incident)':9})

# %%
X=df[['Killed','Wounded','Target_type','Weapon_type','Country','Year','Group']]
Y=df['AttackType']

# %%
X = pd.get_dummies(X, columns = ['Target_type', 'Weapon_type','Country'])

# %%
import pickle

# %%
feature_names = X.columns.tolist()
with open("feature_names.pkl", "wb") as f:
    pickle.dump(feature_names, f)

# %%
X
# Out:
#                                                           Killed  Wounded  \
# Weapon_type
# Biological                                         9149      0.0      0.0
#                                                    9724      0.0      0.0
#                                                    15538     0.0      0.0
#                                                    26683     0.0      0.0
# Chemical                                           934       0.0      4.0
# ...                                                          ...      ...
# Vehicle (not to include vehicle-borne explosive... 24624     0.0      1.0
#                                                    24987     1.0   8191.0
#                                                    27474     0.0      0.0
#                                                    28876     1.0      1.0
#                                                    29639     1.0     19.0
#
#                                                           Year  Group  \
# Weapon_type
# Biological                                         9149   2013      3
#                                                    9724   2013      3
#                                                    15538  1990      2
#                                                    26683  2013      3
# Chemical                                           934    2014    201
# ...                                                        ...    ...
# Vehicle (not to include vehicle-borne explosive... 24624  2016    131
#                                                    24987  2001     21
#                                                    27474  1992      4
#                                                    28876  2015    131
#                                                    29639  2017     89
#
#                                                           Target_type_Abortion Related  \
# Weapon_type
# Biological                                         9149                          False
#                                                    9724                          False
#                                                    15538                         False
#                                                    26683                         False
# Chemical                                           934                           False
# ...                                                                                ...
# Vehicle (not to include vehicle-borne explosive... 24624                         False
#                                                    24987                         False
#                                                    27474                         False
#                                                    28876                         False
#                                                    29639                         False
#
#                                                           Target_type_Airports & Aircraft  \
# Weapon_type
# Biological                                         9149                             False
#                                                    9724                             False
#                                                    15538                            False
#                                                    26683                            False
# Chemical                                           934                              False
# ...                                                                                   ...
# Vehicle (not to include vehicle-borne explosive... 24624                            False
#                                                    24987                            False
#                                                    27474                            False
#                                                    28876                            False
#                                                    29639                            False
#
#                                                           Target_type_Business  \
# Weapon_type
# Biological                                         9149                  False
#                                                    9724                  False
#                                                    15538                 False
#                                                    26683                 False
# Chemical                                           934                   False
# ...                                                                        ...
# Vehicle (not to include vehicle-borne explosive... 24624                 False
#                                                    24987                 False
#                                                    27474                 False
#                                                    28876                 False
#                                                    29639                 False
#
#                                                           Target_type_Educational Institution  \
# Weapon_type
# Biological                                         9149                                 False
#                                                    9724                                 False
#                                                    15538                                False
#                                                    26683                                False
# Chemical                                           934                                  False
# ...                                                                                       ...
# Vehicle (not to include vehicle-borne explosive... 24624                                False
#                                                    24987                                False
#                                                    27474                                False
#                                                    28876                                False
#                                                    29639                                False
#
#                                                           Target_type_Food or Water Supply  \
# Weapon_type
# Biological                                         9149                              False
#                                                    9724                              False
#                                                    15538                             False
#                                                    26683                             False
# Chemical                                           934                               False
# ...                                                                                    ...
# Vehicle (not to include vehicle-borne explosive... 24624                             False
#                                                    24987                             False
#                                                    27474                             False
#                                                    28876                             False
#                                                    29639                             False
#
#                                                           Target_type_Government (Diplomatic)  \
# Weapon_type
# Biological                                         9149                                 False
#                                                    9724                                 False
#                                                    15538                                False
#                                                    26683                                False
# Chemical                                           934                                  False
# ...                                                                                       ...
# Vehicle (not to include vehicle-borne explosive... 24624                                False
#                                                    24987                                False
#                                                    27474                                False
#                                                    28876                                False
#                                                    29639                                False
#
#                                                           ...  \
# Weapon_type                                               ...
# Biological                                         9149   ...
#                                                    9724   ...
#                                                    15538  ...
#                                                    26683  ...
# Chemical                                           934    ...
# ...                                                       ...
# Vehicle (not to include vehicle-borne explosive... 24624  ...
#                                                    24987  ...
#                                                    27474  ...
#                                                    28876  ...
#                                                    29639  ...
#
#                                                           Country_Uzbekistan  \
# Weapon_type
# Biological                                         9149                False
#                                                    9724                False
#                                                    15538               False
#                                                    26683               False
# Chemical                                           934                 False
# ...                                                                      ...
# Vehicle (not to include vehicle-borne explosive... 24624               False
#                                                    24987               False
#                                                    27474               False
#                                                    28876               False
#                                                    29639               False
#
#                                                           Country_Venezuela  \
# Weapon_type
# Biological                                         9149               False
#                                                    9724               False
#                                                    15538              False
#                                                    26683              False
# Chemical                                           934                False
# ...                                                                     ...
# Vehicle (not to include vehicle-borne explosive... 24624              False
#                                                    24987              False
#                                                    27474               True
#                                                    28876              False
#                                                    29639              False
#
#                                                           Country_Vietnam  \
# Weapon_type
# Biological                                         9149             False
#                                                    9724             False
#                                                    15538            False
#                                                    26683            False
# Chemical                                           934              False
# ...                                                                   ...
# Vehicle (not to include vehicle-borne explosive... 24624            False
#                                                    24987            False
#                                                    27474            False
#                                                    28876            False
#                                                    29639            False
#
#                                                           Country_West Bank and Gaza Strip  \
# Weapon_type
# Biological                                         9149                              False
#                                                    9724                              False
#                                                    15538                             False
#                                                    26683                             False
# Chemical                                           934                               False
# ...                                                                                    ...
# Vehicle (not to include vehicle-borne explosive... 24624                              True
#                                                    24987                             False
#                                                    27474                             False
#                                                    28876                              True
#                                                    29639                             False
#
#                                                           Country_West Germany (FRG)  \
# Weapon_type
# Biological                                         9149                        False
#                                                    9724                        False
#                                                    15538                       False
#                                                    26683                       False
# Chemical                                           934                         False
# ...                                                                              ...
# Vehicle (not to include vehicle-borne explosive... 24624                       False
#                                                    24987                       False
#                                                    27474                       False
#                                                    28876                       False
#                                                    29639                       False
#
#                                                           Country_Yemen  \
# Weapon_type
# Biological                                         9149           False
#                                                    9724           False
#                                                    15538          False
#                                                    26683          False
# Chemical                                           934            False
# ...                                                                 ...
# Vehicle (not to include vehicle-borne explosive... 24624          False
#                                                    24987          False
#                                                    27474          False
#                                                    28876          False
#                                                    29639          False
#
#                                                           Country_Yugoslavia  \
# Weapon_type
# Biological                                         9149                False
#                                                    9724                False
#                                                    15538               False
#                                                    26683               False
# Chemical                                           934                 False
# ...                                                                      ...
# Vehicle (not to include vehicle-borne explosive... 24624               False
#                                                    24987               False
#                                                    27474               False
#                                                    28876               False
#                                                    29639               False
#
#                                                           Country_Zaire  \
# Weapon_type
# Biological                                         9149           False
#                                                    9724           False
#                                                    15538          False
#                                                    26683          False
# Chemical                                           934            False
# ...                                                                 ...
# Vehicle (not to include vehicle-borne explosive... 24624          False
#                                                    24987          False
#                                                    27474          False
#                                                    28876          False
#                                                    29639          False
#
#                                                           Country_Zambia  \
# Weapon_type
# Biological                                         9149            False
#                                                    9724            False
#                                                    15538           False
#                                                    26683           False
# Chemical                                           934             False
# ...                                                                  ...
# Vehicle (not to include vehicle-borne explosive... 24624           False
#                                                    24987           False
#                                                    27474           False
#                                                    28876           False
#                                                    29639           False
#
#                                                           Country_Zimbabwe
# Weapon_type
# Biological                                         9149              False
#                                                    9724              False
#                                                    15538             False
#                                                    26683             False
# Chemical                                           934               False
# ...                                                                    ...
# Vehicle (not to include vehicle-borne explosive... 24624             False
#                                                    24987             False
#                                                    27474             False
#                                                    28876             False
#                                                    29639             False
#
# [29672 rows x 203 columns]

# %%
scaler=StandardScaler()
X=scaler.fit_transform(X)
X.shape
# Out:
# (29672, 203)

# %%
df['AttackType'].unique()
# Out:
# array([3, 1, 2, 5, 6, 4, 9, 7, 8])

# %%
X.shape
# Out:
# (29672, 203)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42, stratify=Y
)

# %%
svm_model = SVC()
svm_model.fit(X_train, Y_train)
svm_predictions = svm_model.predict(X_test)
svm_accuracy = accuracy_score(Y_test, svm_predictions)
print("SVM Accuracy:", svm_accuracy)
# Out:
# SVM Accuracy: 0.7834877843302444

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, Y_train)
dt_predictions = dt_model.predict(X_test)
dt_accuracy = accuracy_score(Y_test, dt_predictions)
print("Decision Tree Accuracy:", dt_accuracy)
# Out:
# Decision Tree Accuracy: 0.7843302443133952

# %%
#With sampling
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=700, random_state=42)
clf.fit(X_train,Y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.8256107834877844

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [700],
    'max_depth': [30],
    'min_samples_split': [5],
    'min_samples_leaf': [1]
}

# Perform GridSearchCV
grid_search = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5)
grid_search.fit(X_train, Y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Print the best parameters
print("Best Parameters:", best_params)

# Use the best model
best_model = grid_search.best_estimator_
# Out:
# Best Parameters: {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 700}

# %%
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Model Accuracy:", accuracy)

import pickle

# Save the trained model
with open("terrorism_model.pkl", "wb") as model_file:
    pickle.dump(best_model, model_file)

# Save the scaler
with open("scaler.pkl", "wb") as scaler_file:
    pickle.dump(scaler, scaler_file)
# Out:
# Model Accuracy: 0.8385846672283066

# %%
from sklearn.svm import SVC
from sklearn.multiclass import OneVsOneClassifier, OneVsRestClassifier
from sklearn.metrics import accuracy_score




# OvO
ovo_classifier = OneVsOneClassifier(clf)
ovo_classifier.fit(X_train, Y_train)
ovo_predictions = ovo_classifier.predict(X_test)
ovo_accuracy = accuracy_score(Y_test, ovo_predictions)
print("OvO Accuracy:", ovo_accuracy)

# OvA
ova_classifier = OneVsRestClassifier(clf)
ova_classifier.fit(X_train, Y_train)
ova_predictions = ova_classifier.predict(X_test)
ova_accuracy = accuracy_score(Y_test, ova_predictions)
print("OvA Accuracy:", ova_accuracy)
# Out:
# OvO Accuracy: 0.8303285593934289
# OvA Accuracy: 0.8279696714406066
